# %% [markdown]
# <a href="https://colab.research.google.com/github/shvlade/pythonlab4/blob/master/Untitled3.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import numpy as np
import matplotlib.pyplot as plt
x = np.linspace(0, 10, 100)
y = np.sin(x)
z = np.cos(x)
plt.plot(x, y, label = 'sin(x)',color = 'red')
plt.plot(x, z, label = 'cos(x)', color = 'yellow')
plt.title('Regular graphics')
plt.xlabel('x')
plt.ylabel('y')
plt.legend()
plt.show()

# %%
from matplotlib import pyplot as plt
import numpy as np

x = np.random.normal(0, 1, 1000)
plt.hist(x, bins = 20, color='purple')
plt.title('Гистограмма')
plt.xlabel('Знач')
plt.ylabel('Частота')
plt.show()

# %%
from matplotlib import pyplot as plt
import numpy as np
x = np.random.randint(1, 11, size = (5,5))
print(x)
print(np.mean(x))
print(np.max(x))
print(np.min(x))
print(np.sum(x))
# Out:
# [[ 8  6  6  2 10]
#  [ 2  5  2 10 10]
#  [ 1  9  5  3 10]
#  [ 4  1  6  1  3]
#  [ 5  9  1  6  2]]
# 5.08
# 10
# 1
# 127
